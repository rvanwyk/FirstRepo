# %% [markdown]
# <a href="https://colab.research.google.com/github/rvanwyk/FirstRepo/blob/main/HelloWorldML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# A Hello World, but ML
# Importing TensorFlow, numpy, and keras

import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
# Defining and compiling the ML model

model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
# Provinding the data

xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-2.0, 1.0, 4.0, 7.0, 10.0, 13.0], dtype=float)

# %%
# Train the neural network

model.fit(xs, ys, epochs=200)
# Out:
# Epoch 1/200
# 1/1 [==============================] - 0s 472ms/step - loss: 26.7349
# Epoch 2/200
# 1/1 [==============================] - 0s 11ms/step - loss: 21.0459
# Epoch 3/200
# 1/1 [==============================] - 0s 10ms/step - loss: 16.5698
# Epoch 4/200
# 1/1 [==============================] - 0s 8ms/step - loss: 13.0480
# Epoch 5/200
# 1/1 [==============================] - 0s 12ms/step - loss: 10.2770
# Epoch 6/200
# 1/1 [==============================] - 0s 10ms/step - loss: 8.0967
# Epoch 7/200
# 1/1 [==============================] - 0s 9ms/step - loss: 6.3810
# Epoch 8/200
# 1/1 [==============================] - 0s 5ms/step - loss: 5.0311
# Epoch 9/200
# 1/1 [==============================] - 0s 6ms/step - loss: 3.9687
# Epoch 10/200
# 1/1 [==============================] - 0s 8ms/step - loss: 3.1327
# Epoch 11/200
# 1/1 [==============================] - 0s 6ms/step - loss: 2.4748
# Epoch 12/200
# 1/1 [==============================] - 0s 6ms/step - loss: 1.9569
# ...

# %%
# Use the model to predict

print(model.predict([10.0]))
# Out:
# [[31.093027]]
